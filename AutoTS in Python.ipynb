# %% [markdown]
# <a href="https://colab.research.google.com/github/adrien50/basicprojectmachinelearning/blob/main/AutoTS%20in%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##AutoTS in Python (Tutorial)
#
# AutoTS is an automatic machine learning library in Python which is developed for the task of automatic time series forecasting. You can use this library for any task of time series forecasting such as predicting the stock prices for the next n number of days. In this article, I will take you through a tutorial on the AutoTS library in Python.
# ## What is AutoTS in Python?
#
# AutoTS means Automatic Time Series, it is a machine learning library in Python used for the task of time series forecasting. I recently used it for forecasting the stock prices of Apple for the next 10 days and the resulting figures were so accurate. Some of the popular features of the AutoTS library in Python are:
#
# It can be used to find the best time series forecasting model which depends on the type of data you are using.
#
# It can handle both the univariate and multivariate time series.
#
# It can also handle messy data by removing and filling the NaN values and it can also handle the outliers.
#
# You can use the models provided by this Python library for deployment also.
# These were some of the important features of the AutoTS library in Python. It has more features for time series forecasting, you can explore more about this library from its official documentation from here. In the section below, I will take you through a tutorial on the AutoTS library in Python for the task of stock price prediction.
#
# ## AutoTS in Python (Tutorial)
# If you have never used this Python library for the task of time series forecasting before, then you can easily install it in your system by using the pip command; pip install autots. Now let’s see how to use the AutoTS library in Python for the task of stock price prediction. I will start this task by importing the necessary Python libraries and the dataset:

# %%
# !pip install autots
# Out:
# Collecting autots
#   Downloading https://files.pythonhosted.org/packages/37/04/cd3cdd57d8f27394f6d86f5facc827eabb691b290dc63abb40e3f687163b/AutoTS-0.3.1-py3-none-any.whl (390kB)
#      |████████████████████████████████| 399kB 8.4MB/s
# Requirement already satisfied: pandas>=0.25.* in /usr/local/lib/python3.7/dist-packages (from autots) (1.1.5)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from autots) (1.19.5)
# Requirement already satisfied: statsmodels>=0.10.* in /usr/local/lib/python3.7/dist-packages (from autots) (0.10.2)
# Requirement already satisfied: scikit-learn>=0.20.* in /usr/local/lib/python3.7/dist-packages (from autots) (0.22.2.post1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.*->autots) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.*->autots) (2.8.1)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.10.*->autots) (0.5.1)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.10.*->autots) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.*->autots) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.*->autots) (1.15.0)
# Installing collected packages: autots
# Successfully installed autots-0.3.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("AAPL.csv")
data.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close     Volume
# 0  2020-04-20  69.487503  70.419998  69.212502  69.232498  68.583473  130015200
# 1  2020-04-21  69.070000  69.312500  66.357498  67.092499  66.463539  180991600
# 2  2020-04-22  68.402496  69.474998  68.050003  69.025002  68.377922  116862400
# 3  2020-04-23  68.967499  70.437500  68.717499  68.757500  68.112923  124814400
# 4  2020-04-24  69.300003  70.752502  69.250000  70.742500  70.079315  126161200

# %% [markdown]
# In this tutorial, I am using the stock price data of Apple which has been downloaded from Yahoo Finance. Now before using the AutoTs library for the task of stock price prediction, let’s prepare the data and have a look at the closing stock prices of Apple:

# %%
data = data[["Date", "Close"]]
data["Date"] = pd.to_datetime(data.Date)
data["Close"].plot(figsize=(12, 8), title="Apple Stock Prices", fontsize=20, label="Close Price")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Now let’s see how to use the AutoTS library for the task of automatic time series forecasting:

# %%
from autots import AutoTS
model = AutoTS(forecast_length=10, frequency='infer', 
               ensemble='simple', drop_data_older_than_periods=200)
model = model.fit(data, date_col='Date', value_col='Close', id_col=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/autots/models/sklearn.py:376: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# /usr/local/lib/python3.7/dist-packages/autots/models/sklearn.py:439: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Inferred frequency is: B
# Old data dropped by `drop_data_older_than_periods`.
# Model Number: 1 with model AverageValueNaive in generation 0 of 5
# Model Number: 2 with model AverageValueNaive in generation 0 of 5
# Model Number: 3 with model AverageValueNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 3: AverageValueNaive
# Model Number: 4 with model DatepartRegression in generation 0 of 5
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# Model Number: 5 with model DatepartRegression in generation 0 of 5
# Model Number: 6 with model DatepartRegression in generation 0 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 7 with model DatepartRegression in generation 0 of 5
# Epoch 1/50
# 6/6 [==============================] - 4s 4ms/step - loss: 0.3632
# Epoch 2/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3666
# Epoch 3/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3494
# Epoch 4/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3294
# Epoch 5/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3290
# Epoch 6/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3218
# Epoch 7/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3186
# Epoch 8/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3139
# Epoch 9/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3010
# Epoch 10/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2995
# Epoch 11/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3074
# Epoch 12/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2882
# Epoch 13/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2903
# Epoch 14/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2822
# Epoch 15/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2817
# Epoch 16/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2716
# Epoch 17/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2768
# Epoch 18/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2681
# Epoch 19/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2692
# Epoch 20/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2757
# Epoch 21/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2704
# Epoch 22/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2609
# Epoch 23/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2680
# Epoch 24/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2540
# Epoch 25/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2611
# Epoch 26/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2569
# Epoch 27/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2533
# Epoch 28/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2437
# Epoch 29/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2421
# Epoch 30/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2390
# Epoch 31/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2502
# Epoch 32/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2453
# Epoch 33/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2347
# Epoch 34/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2492
# Epoch 35/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2310
# Epoch 36/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2422
# Epoch 37/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2392
# Epoch 38/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2356
# Epoch 39/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2249
# Epoch 40/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2396
# Epoch 41/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2356
# Epoch 42/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2287
# Epoch 43/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2430
# Epoch 44/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2330
# Epoch 45/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2185
# Epoch 46/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2330
# Epoch 47/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2302
# Epoch 48/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2207
# Epoch 49/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2206
# Epoch 50/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2181
# Model Number: 8 with model ETS in generation 0 of 5
# Model Number: 9 with model ETS in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 9: ETS
# Model Number: 10 with model GLM in generation 0 of 5
# Model Number: 11 with model GLM in generation 0 of 5
# Model Number: 12 with model GLS in generation 0 of 5
# Model Number: 13 with model GLS in generation 0 of 5
# Model Number: 14 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 14: GluonTS
# Model Number: 15 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 15: GluonTS
# Model Number: 16 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 16: GluonTS
# Model Number: 17 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 17: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 18: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 19: GluonTS
# Model Number: 20 with model LastValueNaive in generation 0 of 5
# Model Number: 21 with model LastValueNaive in generation 0 of 5
# Model Number: 22 with model LastValueNaive in generation 0 of 5
# Model Number: 23 with model LastValueNaive in generation 0 of 5
# Model Number: 24 with model SeasonalNaive in generation 0 of 5
# Model Number: 25 with model SeasonalNaive in generation 0 of 5
# Model Number: 26 with model SeasonalNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 26: SeasonalNaive
# Model Number: 27 with model SeasonalNaive in generation 0 of 5
# Model Number: 28 with model UnobservedComponents in generation 0 of 5
# Model Number: 29 with model UnobservedComponents in generation 0 of 5
# Model Number: 30 with model UnobservedComponents in generation 0 of 5
# Model Number: 31 with model VAR in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 31: VAR
# Model Number: 32 with model VAR in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 32: VAR
# Model Number: 33 with model VAR in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 33: VAR
# Model Number: 34 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 34: VECM
# Model Number: 35 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 35: VECM
# Model Number: 36 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 36: VECM
# Model Number: 37 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 37: VECM
# Model Number: 38 with model WindowRegression in generation 0 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:1227: RuntimeWarning:
#
# invalid value encountered in log
# Model Number: 39 with model ZeroesNaive in generation 0 of 5
# Model Number: 40 with model GLM in generation 0 of 5
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 40: GLM
# Model Number: 41 with model AverageValueNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 100') in model 41: AverageValueNaive
# Model Number: 42 with model ETS in generation 0 of 5
# Model Number: 43 with model DatepartRegression in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 43: DatepartRegression
# Model Number: 44 with model WindowRegression in generation 0 of 5
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float32').") in model 44: WindowRegression
# Model Number: 45 with model SeasonalNaive in generation 0 of 5
# Model Number: 46 with model GLM in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 46: GLM
# Model Number: 47 with model RollingRegression in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 47: RollingRegression
# Model Number: 48 with model FBProphet in generation 0 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 49 with model FBProphet in generation 0 of 5
# Model Number: 50 with model GLS in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 50: GLS
# Model Number: 51 with model GLS in generation 0 of 5
# Model Number: 52 with model SeasonalNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 52: SeasonalNaive
# Model Number: 53 with model FBProphet in generation 0 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 54 with model VAR in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 54: VAR
# Model Number: 55 with model ETS in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 55: ETS
# Model Number: 56 with model ETS in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 183') in model 56: ETS
# Model Number: 57 with model LastValueNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 57: LastValueNaive
# Model Number: 58 with model LastValueNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 58: LastValueNaive
# Model Number: 59 with model DatepartRegression in generation 0 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Model Number: 60 with model ETS in generation 0 of 5
# Model Number: 61 with model LastValueNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 61: LastValueNaive
# Model Number: 62 with model GluonTS in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 62: GluonTS
# Model Number: 63 with model AverageValueNaive in generation 0 of 5
# Model Number: 64 with model DatepartRegression in generation 0 of 5
# Epoch 1/100
# 12/12 [==============================] - 4s 4ms/step - loss: 1.0026
# Epoch 2/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9994
# Epoch 3/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0029
# Epoch 4/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0018
# Epoch 5/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0007
# Epoch 6/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0024
# Epoch 7/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0008
# Epoch 8/100
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0026
# Epoch 9/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0017
# Epoch 10/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9993
# Epoch 11/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0030
# Epoch 12/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0019
# Epoch 13/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0007
# Epoch 14/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0017
# Epoch 15/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9989
# Epoch 16/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0009
# Epoch 17/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0030
# Epoch 18/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0029
# Epoch 19/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0016
# Epoch 20/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0003
# Epoch 21/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0018
# Epoch 22/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0011
# Epoch 23/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0009
# Epoch 24/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0017
# Epoch 25/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0012
# Epoch 26/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0014
# Epoch 27/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0016
# Epoch 28/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0012
# Epoch 29/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0021
# Epoch 30/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0017
# Epoch 31/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0019
# Epoch 32/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0011
# Epoch 33/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0014
# Epoch 34/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0011
# Epoch 35/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0011
# Epoch 36/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0004
# Epoch 37/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0002
# Epoch 38/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0001
# Epoch 39/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0007
# Epoch 40/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9992
# Epoch 41/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0018
# Epoch 42/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0005
# Epoch 43/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9997
# Epoch 44/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0017
# Epoch 45/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0003
# Epoch 46/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0008
# Epoch 47/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0014
# Epoch 48/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9988
# Epoch 49/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0024
# Epoch 50/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0003
# Epoch 51/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0010
# Epoch 52/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9972
# Epoch 53/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0013
# Epoch 54/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0017
# Epoch 55/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0008
# Epoch 56/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0033
# Epoch 57/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0038
# Epoch 58/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0004
# Epoch 59/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0033
# Epoch 60/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0006
# Epoch 61/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0015
# Epoch 62/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0007
# Epoch 63/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0015
# Epoch 64/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0018
# Epoch 65/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0026
# Epoch 66/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9997
# Epoch 67/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9998
# Epoch 68/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0010
# Epoch 69/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0006
# Epoch 70/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0022
# Epoch 71/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0022
# Epoch 72/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0004
# Epoch 73/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0003
# Epoch 74/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0005
# Epoch 75/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0005
# Epoch 76/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9994
# Epoch 77/100
# 12/12 [==============================] - 0s 6ms/step - loss: 1.0014
# Epoch 78/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0024
# Epoch 79/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9995
# Epoch 80/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0014
# Epoch 81/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0012
# Epoch 82/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0018
# Epoch 83/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0015
# Epoch 84/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0007
# Epoch 85/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0005
# Epoch 86/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0001
# Epoch 87/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9997
# Epoch 88/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0001
# Epoch 89/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0017
# Epoch 90/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0017
# Epoch 91/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0001
# Epoch 92/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0004
# Epoch 93/100
# 12/12 [==============================] - 0s 6ms/step - loss: 1.0006
# Epoch 94/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0009
# Epoch 95/100
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0009
# Epoch 96/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0009
# Epoch 97/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0004
# Epoch 98/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0021
# Epoch 99/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9987
# Epoch 100/100
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0014
# Model Number: 65 with model AverageValueNaive in generation 0 of 5
# Model Number: 66 with model LastValueNaive in generation 0 of 5
# Model Number: 67 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 67: GluonTS
# Model Number: 68 with model ZeroesNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 68: ZeroesNaive
# Model Number: 69 with model GLM in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 69: GLM
# Model Number: 70 with model GLS in generation 0 of 5
# Model Number: 71 with model UnobservedComponents in generation 0 of 5
# Model Number: 72 with model SeasonalNaive in generation 0 of 5
# Model Number: 73 with model FBProphet in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 73: FBProphet
# Model Number: 74 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 74: VECM
# Model Number: 75 with model SeasonalNaive in generation 0 of 5
# Model Number: 76 with model SeasonalNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 76: SeasonalNaive
# Model Number: 77 with model GLM in generation 0 of 5
# Model Number: 78 with model AverageValueNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 183') in model 78: AverageValueNaive
# Model Number: 79 with model GLS in generation 0 of 5
# New Generation: 1 of 5
# /usr/local/lib/python3.7/dist-packages/autots/models/sklearn.py:439: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# /usr/local/lib/python3.7/dist-packages/autots/models/sklearn.py:376: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Model Number: 80 with model DatepartRegression in generation 1 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 80: DatepartRegression
# Model Number: 81 with model DatepartRegression in generation 1 of 5
# Epoch 1/50
# 6/6 [==============================] - 3s 4ms/step - loss: 0.7366
# Epoch 2/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7394
# Epoch 3/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7374
# Epoch 4/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7440
# Epoch 5/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7305
# Epoch 6/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7431
# Epoch 7/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7432
# Epoch 8/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7337
# Epoch 9/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7320
# Epoch 10/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7347
# Epoch 11/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7277
# Epoch 12/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7392
# Epoch 13/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7321
# Epoch 14/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7320
# Epoch 15/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7394
# Epoch 16/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7335
# Epoch 17/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7350
# Epoch 18/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7280
# Epoch 19/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7310
# Epoch 20/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7397
# Epoch 21/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7262
# Epoch 22/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7252
# Epoch 23/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7300
# Epoch 24/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7246
# Epoch 25/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7350
# Epoch 26/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7353
# Epoch 27/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7282
# Epoch 28/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7304
# Epoch 29/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7415
# Epoch 30/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7361
# Epoch 31/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7272
# Epoch 32/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7285
# Epoch 33/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7372
# Epoch 34/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7254
# Epoch 35/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7327
# Epoch 36/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7312
# Epoch 37/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7349
# Epoch 38/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7225
# Epoch 39/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7275
# Epoch 40/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7379
# Epoch 41/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7260
# Epoch 42/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7267
# Epoch 43/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7398
# Epoch 44/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7284
# Epoch 45/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7262
# Epoch 46/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.7335
# Epoch 47/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7389
# Epoch 48/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7302
# Epoch 49/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7276
# Epoch 50/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7328
# Model Number: 82 with model DatepartRegression in generation 1 of 5
# Template Eval Error: LightGBMError('[gamma]: at least one target label is negative') in model 82: DatepartRegression
# Model Number: 83 with model AverageValueNaive in generation 1 of 5
# Model Number: 84 with model AverageValueNaive in generation 1 of 5
# Model Number: 85 with model AverageValueNaive in generation 1 of 5
# Model Number: 86 with model GLS in generation 1 of 5
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/minpack.py:808: OptimizeWarning:
#
# Covariance of the parameters could not be estimated
#
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 87 with model GLS in generation 1 of 5
# Model Number: 88 with model GLS in generation 1 of 5
# Model Number: 89 with model FBProphet in generation 1 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 90 with model FBProphet in generation 1 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 183') in model 90: FBProphet
# Model Number: 91 with model FBProphet in generation 1 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 91: FBProphet
# Model Number: 92 with model FBProphet in generation 1 of 5
# Model Number: 93 with model WindowRegression in generation 1 of 5
# Model Number: 94 with model WindowRegression in generation 1 of 5
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float32').") in model 94: WindowRegression
# Model Number: 95 with model WindowRegression in generation 1 of 5
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 95: WindowRegression
# Model Number: 96 with model WindowRegression in generation 1 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 96: WindowRegression
# Model Number: 97 with model LastValueNaive in generation 1 of 5
# Model Number: 98 with model LastValueNaive in generation 1 of 5
# Model Number: 99 with model LastValueNaive in generation 1 of 5
# Model Number: 100 with model SeasonalNaive in generation 1 of 5
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/minpack.py:808: OptimizeWarning:
#
# Covariance of the parameters could not be estimated
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/minpack.py:808: OptimizeWarning:
#
# Covariance of the parameters could not be estimated
# Model Number: 101 with model SeasonalNaive in generation 1 of 5
# Model Number: 102 with model SeasonalNaive in generation 1 of 5
# Model Number: 103 with model SeasonalNaive in generation 1 of 5
# Model Number: 104 with model UnobservedComponents in generation 1 of 5
# Model Number: 105 with model UnobservedComponents in generation 1 of 5
# Model Number: 106 with model UnobservedComponents in generation 1 of 5
# Model Number: 107 with model ETS in generation 1 of 5
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
# Model Number: 108 with model ETS in generation 1 of 5
# Model Number: 109 with model ETS in generation 1 of 5
# Model Number: 110 with model ETS in generation 1 of 5
# Model Number: 111 with model GLM in generation 1 of 5
# Model Number: 112 with model GLM in generation 1 of 5
# Model Number: 113 with model GLM in generation 1 of 5
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:890: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/links.py:190: RuntimeWarning:
#
# overflow encountered in exp
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:889: RuntimeWarning:
#
# divide by zero encountered in true_divide
# Model Number: 114 with model GLM in generation 1 of 5
# Model Number: 115 with model ZeroesNaive in generation 1 of 5
# Model Number: 116 with model ZeroesNaive in generation 1 of 5
# Model Number: 117 with model ZeroesNaive in generation 1 of 5
# Model Number: 118 with model GluonTS in generation 1 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 118: GluonTS
# Model Number: 119 with model GluonTS in generation 1 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 119: GluonTS
# Model Number: 120 with model GluonTS in generation 1 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 120: GluonTS
# Model Number: 121 with model GluonTS in generation 1 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 121: GluonTS
# Model Number: 122 with model VAR in generation 1 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 122: VAR
# Model Number: 123 with model VAR in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 123: VAR
# Model Number: 124 with model VAR in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 124: VAR
# Model Number: 125 with model VAR in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 125: VAR
# Model Number: 126 with model VECM in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 126: VECM
# Model Number: 127 with model VECM in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 127: VECM
# Model Number: 128 with model VECM in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 128: VECM
# Model Number: 129 with model VECM in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 129: VECM
# Model Number: 130 with model RollingRegression in generation 1 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 130: RollingRegression
# Model Number: 131 with model RollingRegression in generation 1 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 131: RollingRegression
# Model Number: 132 with model RollingRegression in generation 1 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Model Number: 133 with model RollingRegression in generation 1 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 183') in model 133: RollingRegression
# New Generation: 2 of 5
# Model Number: 134 with model UnobservedComponents in generation 2 of 5
# Model Number: 135 with model UnobservedComponents in generation 2 of 5
# Model Number: 136 with model UnobservedComponents in generation 2 of 5
# /usr/local/lib/python3.7/dist-packages/autots/models/sklearn.py:376: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 137 with model AverageValueNaive in generation 2 of 5
# Model Number: 138 with model AverageValueNaive in generation 2 of 5
# Model Number: 139 with model AverageValueNaive in generation 2 of 5
# Model Number: 140 with model FBProphet in generation 2 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 141 with model FBProphet in generation 2 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 142 with model FBProphet in generation 2 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 143 with model FBProphet in generation 2 of 5
# Model Number: 144 with model SeasonalNaive in generation 2 of 5
# Model Number: 145 with model SeasonalNaive in generation 2 of 5
# Model Number: 146 with model SeasonalNaive in generation 2 of 5
# Model Number: 147 with model SeasonalNaive in generation 2 of 5
# Model Number: 148 with model DatepartRegression in generation 2 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 148: DatepartRegression
# Model Number: 149 with model DatepartRegression in generation 2 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/autots/models/sklearn.py:1499: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Model Number: 150 with model DatepartRegression in generation 2 of 5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# Model Number: 151 with model GLS in generation 2 of 5
# Model Number: 152 with model GLS in generation 2 of 5
# Model Number: 153 with model WindowRegression in generation 2 of 5
# Model Number: 154 with model WindowRegression in generation 2 of 5
# Model Number: 155 with model WindowRegression in generation 2 of 5
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float32').") in model 155: WindowRegression
# Model Number: 156 with model WindowRegression in generation 2 of 5
# Model Number: 157 with model LastValueNaive in generation 2 of 5
# Model Number: 158 with model LastValueNaive in generation 2 of 5
# Model Number: 159 with model LastValueNaive in generation 2 of 5
# Model Number: 160 with model GLM in generation 2 of 5
# Model Number: 161 with model GLM in generation 2 of 5
# Model Number: 162 with model GLM in generation 2 of 5
# Model Number: 163 with model GLM in generation 2 of 5
# Model Number: 164 with model ETS in generation 2 of 5
# Model Number: 165 with model ETS in generation 2 of 5
# Model Number: 166 with model ETS in generation 2 of 5
# Model Number: 167 with model ETS in generation 2 of 5
# Model Number: 168 with model RollingRegression in generation 2 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Model Number: 169 with model RollingRegression in generation 2 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 170 with model RollingRegression in generation 2 of 5
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:195: UserWarning:
#
# Usage of np.ndarray subset (sliced data) is not recommended due to it will double the peak memory cost in LightGBM.
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:195: UserWarning:
#
# Usage of np.ndarray subset (sliced data) is not recommended due to it will double the peak memory cost in LightGBM.
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:195: UserWarning:
#
# Usage of np.ndarray subset (sliced data) is not recommended due to it will double the peak memory cost in LightGBM.
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:195: UserWarning:
#
# Usage of np.ndarray subset (sliced data) is not recommended due to it will double the peak memory cost in LightGBM.
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:195: UserWarning:
#
# Usage of np.ndarray subset (sliced data) is not recommended due to it will double the peak memory cost in LightGBM.
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:195: UserWarning:
#
# Usage of np.ndarray subset (sliced data) is not recommended due to it will double the peak memory cost in LightGBM.
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:195: UserWarning:
#
# Usage of np.ndarray subset (sliced data) is not recommended due to it will double the peak memory cost in LightGBM.
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:195: UserWarning:
#
# Usage of np.ndarray subset (sliced data) is not recommended due to it will double the peak memory cost in LightGBM.
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:195: UserWarning:
#
# Usage of np.ndarray subset (sliced data) is not recommended due to it will double the peak memory cost in LightGBM.
#
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:195: UserWarning:
#
# Usage of np.ndarray subset (sliced data) is not recommended due to it will double the peak memory cost in LightGBM.
# Model Number: 171 with model RollingRegression in generation 2 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Model Number: 172 with model ZeroesNaive in generation 2 of 5
# Model Number: 173 with model ZeroesNaive in generation 2 of 5
# Model Number: 174 with model ZeroesNaive in generation 2 of 5
# Model Number: 175 with model GluonTS in generation 2 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 175: GluonTS
# Model Number: 176 with model GluonTS in generation 2 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 176: GluonTS
# Model Number: 177 with model GluonTS in generation 2 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 177: GluonTS
# Model Number: 178 with model GluonTS in generation 2 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 178: GluonTS
# Model Number: 179 with model VAR in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 179: VAR
# Model Number: 180 with model VAR in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 180: VAR
# Model Number: 181 with model VAR in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 181: VAR
# Model Number: 182 with model VAR in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 182: VAR
# Model Number: 183 with model VECM in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 183: VECM
# Model Number: 184 with model VECM in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 184: VECM
# Model Number: 185 with model VECM in generation 2 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 185: VECM
# Model Number: 186 with model VECM in generation 2 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 186: VECM
# New Generation: 3 of 5
# /usr/local/lib/python3.7/dist-packages/autots/models/sklearn.py:376: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# /usr/local/lib/python3.7/dist-packages/autots/models/sklearn.py:439: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Model Number: 187 with model RollingRegression in generation 3 of 5
# Model Number: 188 with model RollingRegression in generation 3 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Model Number: 189 with model RollingRegression in generation 3 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Model Number: 190 with model RollingRegression in generation 3 of 5
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 190: RollingRegression
# Model Number: 191 with model UnobservedComponents in generation 3 of 5
# ...
# Model Number: 18 of 53 with model FBProphet for Validation 2
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 19 of 53 with model DatepartRegression for Validation 2
# Model Number: 20 of 53 with model FBProphet for Validation 2
# Model Number: 21 of 53 with model AverageValueNaive for Validation 2
# Model Number: 22 of 53 with model AverageValueNaive for Validation 2
# Model Number: 23 of 53 with model AverageValueNaive for Validation 2
# Model Number: 24 of 53 with model UnobservedComponents for Validation 2
# Model Number: 25 of 53 with model FBProphet for Validation 2
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 26 of 53 with model AverageValueNaive for Validation 2
# Model Number: 27 of 53 with model GLS for Validation 2
# Model Number: 28 of 53 with model ZeroesNaive for Validation 2
# Model Number: 29 of 53 with model UnobservedComponents for Validation 2
# Model Number: 30 of 53 with model ETS for Validation 2
# Model Number: 31 of 53 with model UnobservedComponents for Validation 2
# Model Number: 32 of 53 with model SeasonalNaive for Validation 2
# Model Number: 33 of 53 with model SeasonalNaive for Validation 2
# Model Number: 34 of 53 with model DatepartRegression for Validation 2
# Epoch 1/100
# 8/8 [==============================] - 5s 4ms/step - loss: 1.0053
# Epoch 2/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0022
# Epoch 3/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0003
# Epoch 4/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0004
# Epoch 5/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0006
# Epoch 6/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0013
# Epoch 7/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0024
# Epoch 8/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0008
# Epoch 9/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9987
# Epoch 10/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0009
# Epoch 11/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0011
# Epoch 12/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0038
# Epoch 13/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0009
# Epoch 14/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9979
# Epoch 15/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0027
# Epoch 16/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0026
# Epoch 17/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0044
# Epoch 18/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.9995
# Epoch 19/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0019
# Epoch 20/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0019
# Epoch 21/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0017
# Epoch 22/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0021
# Epoch 23/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0017
# Epoch 24/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9991
# Epoch 25/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0018
# Epoch 26/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0022
# Epoch 27/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0018
# Epoch 28/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0015
# Epoch 29/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0011
# Epoch 30/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0027
# Epoch 31/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0006
# Epoch 32/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0007
# Epoch 33/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0021
# Epoch 34/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0003
# Epoch 35/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0027
# Epoch 36/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0021
# Epoch 37/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0011
# Epoch 38/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0015
# Epoch 39/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0000
# Epoch 40/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0034
# Epoch 41/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0010
# Epoch 42/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0008
# Epoch 43/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0012
# Epoch 44/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.9992
# Epoch 45/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0004
# Epoch 46/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0024
# Epoch 47/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0019
# Epoch 48/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0000
# Epoch 49/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0019
# Epoch 50/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.9986
# Epoch 51/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0001
# Epoch 52/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0010
# Epoch 53/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0015
# Epoch 54/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0011
# Epoch 55/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0010
# Epoch 56/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0015
# Epoch 57/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0009
# Epoch 58/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0021
# Epoch 59/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0008
# Epoch 60/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0041
# Epoch 61/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0007
# Epoch 62/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0032
# Epoch 63/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0027
# Epoch 64/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0006
# Epoch 65/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0015
# Epoch 66/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0003
# Epoch 67/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0006
# Epoch 68/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9988
# Epoch 69/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0012
# Epoch 70/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0010
# Epoch 71/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0011
# Epoch 72/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0011
# Epoch 73/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9994
# Epoch 74/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0027
# Epoch 75/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0008
# Epoch 76/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.9996
# Epoch 77/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0002
# Epoch 78/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0045
# Epoch 79/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0007
# Epoch 80/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0010
# Epoch 81/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0012
# Epoch 82/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0017
# Epoch 83/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0018
# Epoch 84/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.9983
# Epoch 85/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0010
# Epoch 86/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0029
# Epoch 87/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0002
# Epoch 88/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0020
# Epoch 89/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0013
# Epoch 90/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0009
# Epoch 91/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0029
# Epoch 92/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9996
# Epoch 93/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.9998
# Epoch 94/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0019
# Epoch 95/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0006
# Epoch 96/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.9993
# Epoch 97/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.9992
# Epoch 98/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0018
# Epoch 99/100
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0013
# Epoch 100/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0010
# Model Number: 35 of 53 with model SeasonalNaive for Validation 2
# Model Number: 36 of 53 with model ETS for Validation 2
# Model Number: 37 of 53 with model ETS for Validation 2
# Model Number: 38 of 53 with model GLS for Validation 2
# Model Number: 39 of 53 with model GLS for Validation 2
# Model Number: 40 of 53 with model SeasonalNaive for Validation 2
# Model Number: 41 of 53 with model DatepartRegression for Validation 2
# Epoch 1/50
# 4/4 [==============================] - 3s 6ms/step - loss: 0.6454
# Epoch 2/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6648
# Epoch 3/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6684
# Epoch 4/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6819
# Epoch 5/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6497
# Epoch 6/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6830
# Epoch 7/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6727
# Epoch 8/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6550
# Epoch 9/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6664
# Epoch 10/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6748
# Epoch 11/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6556
# Epoch 12/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6681
# Epoch 13/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6782
# Epoch 14/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6664
# Epoch 15/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6669
# Epoch 16/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6540
# Epoch 17/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6542
# Epoch 18/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6597
# Epoch 19/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6657
# Epoch 20/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6601
# Epoch 21/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6633
# Epoch 22/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6508
# Epoch 23/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6679
# Epoch 24/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6520
# Epoch 25/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6603
# Epoch 26/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6561
# Epoch 27/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6664
# Epoch 28/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6580
# Epoch 29/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6613
# Epoch 30/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6508
# Epoch 31/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6662
# Epoch 32/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6624
# Epoch 33/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6551
# Epoch 34/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6551
# Epoch 35/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6529
# Epoch 36/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6508
# Epoch 37/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6494
# Epoch 38/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6609
# Epoch 39/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6631
# Epoch 40/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6571
# Epoch 41/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6606
# Epoch 42/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6569
# Epoch 43/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6574
# Epoch 44/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6677
# Epoch 45/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6676
# Epoch 46/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6536
# Epoch 47/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6570
# Epoch 48/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6598
# Epoch 49/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6576
# Epoch 50/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6540
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6317171b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6317171b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model Number: 42 of 53 with model WindowRegression for Validation 2
# Model Number: 43 of 53 with model DatepartRegression for Validation 2
# Model Number: 44 of 53 with model DatepartRegression for Validation 2
# Model Number: 45 of 53 with model ETS for Validation 2
# Model Number: 46 of 53 with model WindowRegression for Validation 2
# Model Number: 47 of 53 with model WindowRegression for Validation 2
# Model Number: 48 of 53 with model WindowRegression for Validation 2
# Model Number: 49 of 53 with model WindowRegression for Validation 2
# Model Number: 50 of 53 with model LastValueNaive for Validation 2
# Model Number: 51 of 53 with model GLM for Validation 2
# Model Number: 52 of 53 with model LastValueNaive for Validation 2
# Model Number: 53 of 53 with model GLM for Validation 2

# %% [markdown]
# In the code section above, I have set the forecast_length parameter as 10, which means the period for which we want to predict the stock prices. So in the output, we will get the closing stock prices of Apple for the next 10 days. So let’s use the predict function and have a look at the output:

# %%
prediction = model.predict()
forecast = prediction.forecast
print("Stock Price Prediction of Apple")
print(forecast)
# Out:
# Stock Price Prediction of Apple
#                  Close
# 2021-04-19  132.443246
# 2021-04-20  132.514943
# 2021-04-21  132.586561
# 2021-04-22  132.658101
# 2021-04-23  132.729564
# 2021-04-26  132.943486
# 2021-04-27  133.014639
# 2021-04-28  133.085715
# 2021-04-29  133.156715
# 2021-04-30  133.227638

# %% [markdown]
# AutoTS means automatic time series, it is an AutoML library in Python which can be used for every task of the time series forecasting. I hope you liked this article on a tutorial on the AutoTS library in Python. Feel free to ask your valuable questions in the comments section below.
